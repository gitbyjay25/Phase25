# %% [markdown]
# <a href="https://colab.research.google.com/github/gitbyjay25/Phase25/blob/main/Pandas1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

# %%
file=files.upload()
# Out:
#      <input type="file" id="files-4540f437-4cd7-4529-9939-6871cd9d355d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4540f437-4cd7-4529-9939-6871cd9d355d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv("Iris.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal.length  149 non-null    float64
#  1   sepal.width   149 non-null    float64
#  2   petal.length  149 non-null    float64
#  3   petal.width   150 non-null    float64
#  4   variety       149 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.head(10)
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          0.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           NaN          0.2  Setosa
# 5           5.4          3.9           1.7          0.4  Setosa
# 6           4.6          3.4           1.4          0.3  Setosa
# 7           5.0          3.4           1.5          0.2  Setosa
# 8           4.4          2.9           1.4          0.2  Setosa
# 9           4.9          3.1           1.5          0.1  Setosa

# %%
df.dropna()
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          0.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 5             5.4          3.9           1.7          0.4     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [146 rows x 5 columns]

# %%
df.fillna(0)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          0.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           0.0          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          0.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           NaN          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
#df.fillna(0,inplace=True)   : Replace the  Nan with 0 and make changes to the df

# %%
df.rename(columns={"sepal.length":"SL"},inplace=True)

# %%
df
# Out:
#       SL  sepal.width  petal.length  petal.width    variety
# 0    5.1          3.5           1.4          0.2     Setosa
# 1    4.9          0.0           1.4          0.2     Setosa
# 2    4.7          3.2           1.3          0.2     Setosa
# 3    4.6          3.1           1.5          0.2     Setosa
# 4    5.0          3.6           NaN          0.2     Setosa
# ..   ...          ...           ...          ...        ...
# 145  6.7          3.0           5.2          2.3  Virginica
# 146  6.3          2.5           5.0          1.9  Virginica
# 147  6.5          3.0           5.2          2.0  Virginica
# 148  6.2          3.4           5.4          2.3  Virginica
# 149  5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df.fillna(0,inplace=True)

# %%
df
# Out:
#       SL  sepal.width  petal.length  petal.width    variety
# 0    5.1          3.5           1.4          0.2     Setosa
# 1    4.9          0.0           1.4          0.2     Setosa
# 2    4.7          3.2           1.3          0.2     Setosa
# 3    4.6          3.1           1.5          0.2     Setosa
# 4    5.0          3.6           0.0          0.2     Setosa
# ..   ...          ...           ...          ...        ...
# 145  6.7          3.0           5.2          2.3  Virginica
# 146  6.3          2.5           5.0          1.9  Virginica
# 147  6.5          3.0           5.2          2.0  Virginica
# 148  6.2          3.4           5.4          2.3  Virginica
# 149  5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   SL            150 non-null    float64
#  1   sepal.width   150 non-null    float64
#  2   petal.length  150 non-null    float64
#  3   petal.width   150 non-null    float64
#  4   variety       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df["SL"]=df["SL"].astype(int)

# %%
df
# Out:
#      SL  sepal.width  petal.length  petal.width    variety
# 0     5          3.5           1.4          0.2     Setosa
# 1     4          0.0           1.4          0.2     Setosa
# 2     4          3.2           1.3          0.2     Setosa
# 3     4          3.1           1.5          0.2     Setosa
# 4     5          3.6           0.0          0.2     Setosa
# ..   ..          ...           ...          ...        ...
# 145   6          3.0           5.2          2.3  Virginica
# 146   6          2.5           5.0          1.9  Virginica
# 147   6          3.0           5.2          2.0  Virginica
# 148   6          3.4           5.4          2.3  Virginica
# 149   5          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   SL            150 non-null    int64
#  1   sepal.width   150 non-null    float64
#  2   petal.length  150 non-null    float64
#  3   petal.width   150 non-null    float64
#  4   variety       150 non-null    object
# dtypes: float64(3), int64(1), object(1)
# memory usage: 6.0+ KB

# %%
len(df)
# Out:
# 150

# %%
df["Zeros"]=[0 for i in range(len(df))]

# %%
df
# Out:
#      SL  sepal.width  petal.length  petal.width    variety  Zeros  Zeros + 2
# 0     5          3.5           1.4          0.2     Setosa      0          0
# 1     4          0.0           1.4          0.2     Setosa      0          0
# 2     4          3.2           1.3          0.2     Setosa      0          0
# 3     4          3.1           1.5          0.2     Setosa      0          0
# 4     5          3.6           0.0          0.2     Setosa      0          0
# ..   ..          ...           ...          ...        ...    ...        ...
# 145   6          3.0           5.2          2.3  Virginica      0          0
# 146   6          2.5           5.0          1.9  Virginica      0          0
# 147   6          3.0           5.2          2.0  Virginica      0          0
# 148   6          3.4           5.4          2.3  Virginica      0          0
# 149   5          3.0           5.1          1.8  Virginica      0          0
#
# [150 rows x 7 columns]

# %%
df.drop("Zeros + 2",axis=1,inplace=True)

# %%
df
# Out:
#      SL  sepal.width  petal.length  petal.width    variety  Zeros
# 0     5          3.5           1.4          0.2     Setosa      0
# 1     4          0.0           1.4          0.2     Setosa      0
# 2     4          3.2           1.3          0.2     Setosa      0
# 3     4          3.1           1.5          0.2     Setosa      0
# 4     5          3.6           0.0          0.2     Setosa      0
# ..   ..          ...           ...          ...        ...    ...
# 145   6          3.0           5.2          2.3  Virginica      0
# 146   6          2.5           5.0          1.9  Virginica      0
# 147   6          3.0           5.2          2.0  Virginica      0
# 148   6          3.4           5.4          2.3  Virginica      0
# 149   5          3.0           5.1          1.8  Virginica      0
#
# [150 rows x 6 columns]

# %%
def fx(i):
  return i+2
df["Zeros + 2"]=df["Zeros"].apply(fx)

# %%
df
# Out:
#      SL  sepal.width  petal.length  petal.width    variety  Zeros  Zeros + 2
# 0     5          3.5           1.4          0.2     Setosa      0          0
# 1     4          0.0           1.4          0.2     Setosa      0          0
# 2     4          3.2           1.3          0.2     Setosa      0          0
# 3     4          3.1           1.5          0.2     Setosa      0          0
# 4     5          3.6           0.0          0.2     Setosa      0          0
# ..   ..          ...           ...          ...        ...    ...        ...
# 145   6          3.0           5.2          2.3  Virginica      0          0
# 146   6          2.5           5.0          1.9  Virginica      0          0
# 147   6          3.0           5.2          2.0  Virginica      0          0
# 148   6          3.4           5.4          2.3  Virginica      0          0
# 149   5          3.0           5.1          1.8  Virginica      0          0
#
# [150 rows x 7 columns]

# %%
df.to_csv("New_Iris.csv")

# %%
files.download("New_Iris.csv")
